# %%
import SharedArray as sa
import numpy as np
import glob

# %%
feature_dirs = glob.glob('/home/public2/share_yw/data/*.npy')

# %%
feature_names = [i.split('/')[-1].split('.')[0] for i in feature_dirs]

# %%
for name in feature_names:
    sa.delete(name)

# %%
for feature_dir in feature_dirs:
    feature_name = 'q'+feature_dir.split('/')[-1].split('.')[0]
    feature = np.load(feature_dir)
    print(feature_name,feature.shape)
    try:
        sa.create(feature_name, feature.shape, dtype=np.float32)
    except:
        print('already exist')
    try:
        tmp=sa.attach(feature_name)
        tmp[:] = feature
    except:
        print('already attached')
    print(feature_name, 'done')
    print('-'*20)
# Out:
# qopen (729, 16, 6000)
# qopen done
# --------------------
# qhigh (729, 16, 6000)
# qhigh done
# --------------------
# qlow (729, 16, 6000)
# qlow done
# --------------------
# qclose (729, 16, 6000)
# qclose done
# --------------------
# qvolume (729, 16, 6000)
# qvolume done
# --------------------
# qamount (729, 16, 6000)
# qamount done
# --------------------
# qvwap (729, 16, 6000)
# qvwap done
# --------------------
# qyesterdayclose (729, 16, 6000)
# qyesterdayclose done
# --------------------
# qtodayopen (729, 16, 6000)
# qtodayopen done
# --------------------
# qcumhigh (729, 16, 6000)
# qcumhigh done
# --------------------
# qcumlow (729, 16, 6000)
# qcumlow done
# --------------------
# qcumvolume (729, 16, 6000)
# qcumvolume done
# --------------------
# qyesterdayvwap (729, 16, 6000)
# qyesterdayvwap done
# --------------------
# qtwap (729, 16, 6000)
# qtwap done
# --------------------
# qret1 (729, 16, 6000)
# qret1 done
# --------------------
# qret5 (729, 16, 6000)
# ...

# %%
import numpy as np

# %%
with open('./features.txt') as f:
    features = f.readlines()

# %%
features = ['q'+i.split('=')[0].strip() for i in features]

# %%
features
# Out:
# ['qopen',
#  'qhigh',
#  'qlow',
#  'qclose',
#  'qvolume',
#  'qamount',
#  'qvwap',
#  'qyesterdayclose',
#  'qtodayopen',
#  'qcumhigh',
#  'qcumlow',
#  'qcumvolume',
#  'qyesterdayvwap',
#  'qtwap',
#  'qret1',
#  'qret5',
#  'qret10',
#  'qyesterdayskip',
#  'q',
#  'qintra_midprices_5_mean',
#  'qintra_midprices_5_std',
#  'qintra_abv_5_mean',
#  'qintra_abv_5_std',
#  'qintra_deltabuy_5_mean',
#  'qintra_deltabuy_5_stdev',
#  'qintra_deltasell_5_mean',
#  'qintra_deltasell_5_stdev',
#  'qintra_deltanetbuy_5_mean',
#  'qintra_deltanetbuy_5_stdev',
#  'qintra_cumbidval_5_mean',
#  'qintra_cumbidval_5_stdev',
#  'qintra_cumaskval_5_mean',
#  'qintra_cumaskval_5_stdev',
#  'qintra_bidheight_5_mean',
#  'qintra_askheight_5_mean',
#  'qintra_midprice10_ret_mean',
#  'qintra_midprice10_ret_stdev',
#  'qintra_midp10vol_corr',
#  'qintra_price5avgmidp11',
#  'qintra_spreadavgmidp11',
#  'qintra_midp10riserate_5',
#  'qintra_midp10riserate_20',
#  'qintra_midp10riserate_100',
# ...
