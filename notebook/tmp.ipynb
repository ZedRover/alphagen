# %%
import numpy as np
import pandas as pd

# %%
df = np.memmap("A:/sa/snapshot/000537.dat",dtype=np.float32,).reshape(-1,54)

# %%
df = pd.DataFrame(df)

# %%
df.describe()
# Out:
#                  0             1             2             3             4   \
# count  1.828412e+06  1.828412e+06  1.828412e+06  1.828412e+06  1.828412e+06
# mean   1.326007e+01  1.323889e+01  1.358585e+01  1.290630e+01  1.323040e+01
# std    5.509440e+00  5.503941e+00  5.719088e+00  5.284169e+00  5.496660e+00
# min    4.370000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.075000e+01  1.058000e+01  1.085000e+01  1.015000e+01  1.063000e+01
# 50%    1.342000e+01  1.338000e+01  1.365000e+01  1.310000e+01  1.336000e+01
# 75%    1.668000e+01  1.664000e+01  1.697000e+01  1.605000e+01  1.652000e+01
# max    2.830000e+01  2.830000e+01  2.915000e+01  2.820000e+01  2.915000e+01
#
#                  5             6            7             8             9   \
# count  1.827937e+06  1.827937e+06    1828412.0  1.828412e+06  1.828412e+06
# mean   6.000059e+03  9.005115e+04   15463547.0  2.380141e+08  1.921188e+04
# ...

# %%
import sys
sys.path.append("../")
from alphagen.utils.pytorch_utils import normalize_by_day
